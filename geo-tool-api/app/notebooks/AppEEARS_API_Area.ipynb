# %% [markdown]
# # Getting Started with the AρρEEARS API: Submitting and Downloading an Area Request
# ### This tutorial demonstrates how to use Python to connect to the AρρEEARS API
# The Application for Extracting and Exploring Analysis Ready Samples ([AρρEEARS](https://appeears.earthdatacloud.nasa.gov/)) offers a simple and efficient way to access and transform geospatial data from a variety of federal data archives in an easy-to-use web application interface. AρρEEARS enables users to subset [geospatial data](https://appeears.earthdatacloud.nasa.gov/products) spatially, temporally, and by band/layer for point and area samples. AρρEEARS returns not only the requested data, but also the associated quality values, and offers interactive visualizations with summary statistics in the web interface.  The [AρρEEARS API](https://appeears.earthdatacloud.nasa.gov/api/) offers users **programmatic access** to all features available in AρρEEARS, with the exception of visualizations. The API features are demonstrated in this notebook.
# ***
# ### Example: Submit an area request using a U.S. National Park boundary as the region of interest for extracting elevation, vegetation and land surface temperature data
# Connect to the AρρEEARS API, query the list of available products, submit an area sample request, download the request, become familiar with the AρρEEARS Quality API, and import the results into Python for visualization. AρρEEARS area sample requests allow users to subset their desired data by spatial area via vector polygons (shapefiles or GeoJSONs). Users can also reproject and reformat the output data. AρρEEARS returns the valid data from the parameters defined within the sample request.
# #### Data Used in the Example:
# - Data layers:
#     - NASA MEaSUREs Shuttle Radar Topography Mission (SRTM) Version 3 Digital Elevation Model
#         - [SRTMGL1_NC.003](https://doi.org/10.5067/MEaSUREs/SRTM/SRTMGL1.003), 30m, static: 'SRTM_DEM'
#     - Combined MODIS Leaf Area Index (LAI)
#         - [MCD15A3H.006](https://doi.org/10.5067/MODIS/MCD15A3H.006), 500m, 4 day: 'Lai_500m'
#     - Terra MODIS Land Surface Temperature
#         - [MOD11A2.061](https://doi.org/10.5067/MODIS/MOD11A2.061), 1000m, 8 day: 'LST_Day_1km', 'LST_Night_1km'
# ***
# # Topics Covered:
# 1. **Getting Started**
#     1a. Set Up the Working Environment
#     1b. Login [Login]
# 2. **Query Available Products [Product API]**
#     2a. Search and Explore Available Products [List Products]
#     2b. Search and Explore Available Layers [List Layers]
# 3. **Submit an Area Request [Tasks]**
#     3a. Import a Shapefile
#     3b. Search and Explore Available Projections [Spatial API]
#     3c. Compile a JSON [Task Object]
#     3d. Submit a Task Request [Submit Task]
#     3e. Retrieve Task Status [Retrieve Task]
# 4. **Download a Request [Bundle API]**
#     4a. Explore Files in Request Output [List Files]
#     4b. Download Files in a Request (Automation) [Download File]
# 5. **Explore AρρEEARS Quality Service [Quality API]**
#     5a. List Quality Layers [List Quality Layers]
#     5b. Show Quality Values [List Quality Values]
#     5c. Decode Quality Values [Decode Quality Values]
# 6. **BONUS: Import Request Output and Visualize**
#     6a. Import a GeoTIFF
#     6b. Plot a GeoTIFF
# ***
# ### Dependencies:
# - This tutorial was tested using Python 3.6.1.
# - A [NASA Earthdata Login](https://urs.earthdata.nasa.gov/) account is required to complete this tutorial. You can create an account at the link provided.
# - To execute section 6, the [Geospatial Data Abstraction Library](http://www.gdal.org/) (GDAL) is required.
# ***
# ### AρρEEARS Information:
# To access AρρEEARS, visit: https://appeears.earthdatacloud.nasa.gov/
# > For comprehensive documentation of the full functionality of the AρρEEARS API, please see the AρρEEARS [API Documentation](https://appeears.earthdatacloud.nasa.gov/api/)
#
# Throughout the tutorial, specific sections of the API documentation can be accessed by clicking on the bracketed [] links in the section headings.
# ***
# ### Files Used in this Tutorial:
# - [Administrative Boundaries of National Park System Units 12/31/2017 - National Geospatial Data Asset (NGDA) NPS National Parks Dataset](https://irma.nps.gov/DataStore/DownloadFile/594958)
#
# ### Source Code used to Generate this Tutorial:
# - [Jupyter Notebook](https://git.earthdata.nasa.gov/projects/LPDUR/repos/appeears-api-getting-started/browse/AppEEARS_API_Area.ipynb)

# %%
# moun my google drive and copy a directory called colab notebooks/AppEEARS_API/Data to this instace
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/AppEEARS_API/Data" ./Data/

# %% [markdown]
# ***

# %% [markdown]
# # 1. Getting Started

# %% [markdown]
# ***
# ## 1a. Set Up the Working Environment
# #### Import the required packages, set the input/working directory, and create an output directory for the results.

# %%
# Import packages
import requests as r
import getpass, pprint, time, os, cgi, json
import geopandas as gpd
import pandas as pd

# %% [markdown]
# #### If you are missing any of the packages above, download them in order to use the full functionality of this tutorial.

# %%
# Set input directory, change working directory
inDir = './'           # IMPORTANT: Update to reflect directory on your OS
os.chdir(inDir)                                      # Change to working directory
api = 'https://appeears.earthdatacloud.nasa.gov/api/'  # Set the AρρEEARS API to a variable

# %% [markdown]
# <div class="alert alert-block alert-warning" >
# <b>If you plan to execute this tutorial on your own OS, `inDir` above needs to be changed.</b>
# </div>

# %% [markdown]
# ***
# ## 1b. Login[[Login](https://appeears.earthdatacloud.nasa.gov/api/#login)]
# #### To submit a request, you must first login to the AρρEEARS API. The AρρEEARS API requires the same [NASA Earthdata Login](https://urs.earthdata.nasa.gov/) as the AρρEEARS user interface. Use the `getpass` package to enter your NASA Earthdata login **Username** and **Password**. When prompted after executing the code block below, enter your username followed by your password.

# %%
user = 'zmuramasaaa'      # Input NASA Earthdata Login Username
password = '_Danker17890'  # Input NASA Earthdata Login Password

# %% [markdown]
# #### Use the `requests` package to post your username and password. A successful login will provide you with a token to be used later in this tutorial to submit a request. For more information or if you are experiencing difficulties, please see the [API Documentation](https://lpdaacsvc.cr.usgs.gov/appeears/api/?language=Python%203#login).

# %%
token_response = r.post('{}login'.format(api), auth=(user, password)).json() # Insert API URL, call login service, provide credentials & return json
token_response                                                               # Print response
# Out:
# {'token_type': 'Bearer',
#  'token': 'l8XM6Zt5Ya6sJHasyv400Bc9QigzCFl1w3bWHtHkiYFiEQdNkKQKRjw9CeoHzxCsQ03uhQ2Ey5nA9o_dLyJeyQ',
#  'expiration': '2024-10-03T23:48:51Z'}

# %% [markdown]
# #### Above, you should see a Bearer token. Notice that this token will expire approximately 48 hours after being acquired.
# ***
# # 2. Query Available Products [[Product API](https://appeears.earthdatacloud.nasa.gov/api/#product)]
# ## 2a. Search and Explore Available Products [[List Products](https://appeears.earthdatacloud.nasa.gov/api/#list-products)]
# #### The product API provides details about all of the products and layers available in AρρEEARS. Below, call the product API to list all of the products available in AρρEEARS.

# %%
product_response = r.get('{}product'.format(api)).json()                         # request all products in the product service
print('AρρEEARS currently supports {} products.'.format(len(product_response)))  # Print no. products available in AppEEARS
# Out:
# AρρEEARS currently supports 157 products.

# %% [markdown]
# #### Next, create a dictionary indexed by product name, making it easier to query a specific product.

# %%
products_dataframe = pd.DataFrame(product_response)

# %%
list(products_dataframe.columns)
# Out:
# ['Product',
#  'Platform',
#  'Description',
#  'RasterType',
#  'Resolution',
#  'TemporalGranularity',
#  'Version',
#  'Available',
#  'DocLink',
#  'Source',
#  'TemporalExtentStart',
#  'TemporalExtentEnd',
#  'Deleted',
#  'DOI',
#  'Info',
#  'ProductAndVersion']

# %%
products_dataframe = products_dataframe[
    products_dataframe['Available'] == True
]

products_dataframe = products_dataframe[
    products_dataframe['Deleted'] == False
]

# %%
products_dataframe = products_dataframe[[
 'ProductAndVersion',
 'Platform',
 'Description',
 'RasterType',
 'Resolution',
 'TemporalGranularity',
 'DocLink',
 'Source',
 'TemporalExtentStart',
 'TemporalExtentEnd',
 'Info',
]]

# %%
products_dataframe.head()
# Out:
#            ProductAndVersion        Platform  \
# 0     GPW_DataQualityInd.411             GPW
# 1    GPW_UN_Adj_PopCount.411             GPW
# 2  GPW_UN_Adj_PopDensity.411             GPW
# 3   GPW_Basic_Demog_Char.411             GPW
# 4                MCD12Q1.061  Combined MODIS
#
#                                          Description RasterType Resolution  \
# 0  Quality of Input Data for Population Count and...       Tile      1000m
# 1                       UN-adjusted Population Count       Tile      1000m
# 2                     UN-adjusted Population Density       Tile      1000m
# 3  Basic Demographic Characteristics - Population...       Tile      1000m
# 4                                    Land Cover Type       Tile       500m
#
#   TemporalGranularity                                    DocLink   Source  \
# 0        Quinquennial           https://doi.org/10.7927/H42Z13KG    SEDAC
# 1        Quinquennial           https://doi.org/10.7927/H4PN93PB    SEDAC
# 2        Quinquennial           https://doi.org/10.7927/H4F47M65    SEDAC
# 3              Static           https://doi.org/10.7927/H46M34XX    SEDAC
# 4              Yearly  https://doi.org/10.5067/MODIS/MCD12Q1.061  LP DAAC
#
#   TemporalExtentStart TemporalExtentEnd Info
# 0          2000-01-01        2020-12-31   {}
# 1          2000-01-01        2020-12-31   {}
# 2          2000-01-01        2020-12-31   {}
# 3          2010-01-01        2010-01-01   {}
# 4          2001-01-01        2020-12-31   {}

# %%
products_dataframe.tail()
# Out:
#           ProductAndVersion Platform  \
# 152        EMIT_L2A_RFL.001     EMIT
# 153  EMIT_L2A_RFLUNCERT.001     EMIT
# 154       EMIT_L2A_MASK.001     EMIT
# 155        EMIT_L2B_MIN.001     EMIT
# 156  EMIT_L2B_MINUNCERT.001     EMIT
#
#                                            Description RasterType Resolution  \
# 152                      Estimated Surface Reflectance      Swath        60m
# 153                        L2A Reflectance Uncertainty      Swath        60m
# 154                              L2A Reflectance Masks      Swath        60m
# 155    Estimated Mineral Identification and Band Depth      Swath        60m
# 156  L2B Mineral Identification and Band Depth Unce...      Swath        60m
#
#     TemporalGranularity                                      DocLink   Source  \
# 152       ISS-dependent  https://doi.org/10.5067/EMIT/EMITL2ARFL.001  LP DAAC
# 153       ISS-dependent  https://doi.org/10.5067/EMIT/EMITL2ARFL.001  LP DAAC
# 154       ISS-dependent  https://doi.org/10.5067/EMIT/EMITL2ARFL.001  LP DAAC
# 155       ISS-dependent  https://doi.org/10.5067/EMIT/EMITL2BMIN.001  LP DAAC
# 156       ISS-dependent  https://doi.org/10.5067/EMIT/EMITL2BMIN.001  LP DAAC
#
#     TemporalExtentStart TemporalExtentEnd  \
# 152          2022-08-09           Present
# 153          2022-08-09           Present
# 154          2022-08-09           Present
# 155          2022-08-09           Present
# 156          2022-08-09           Present
#
#                                                   Info
# 152  {'source_file_prefix': 'EMIT_L2A_RFL_', 'cmr_p...
# 153  {'source_file_prefix': 'EMIT_L2A_RFLUNCERT_', ...
# 154  {'source_file_prefix': 'EMIT_L2A_MASK_', 'cmr_...
# 155  {'source_file_prefix': 'EMIT_L2B_MIN_', 'cmr_p...
# 156  {'source_file_prefix': 'EMIT_L2B_MINUNCERT_', ...

# %%
products_dataframe.shape
# Out:
# (157, 11)

# %% [markdown]
# #### The product service provides many useful details, including if a product is currently available in AρρEEARS, a description, and information on the spatial and temporal resolution.

# %% [markdown]
# #### Get Land surface reflectance products

# %%
query_string = 'Land Surface Reflectance'

# %%
filtered_products = products_dataframe[
    products_dataframe['Description'].str.contains(query_string)
]

filtered_products
# Out:
#     ProductAndVersion                           Platform  \
# 123        HLSS30.020  Harmonized Landsat and Sentinel-2
# 124        HLSL30.020  Harmonized Landsat and Sentinel-2
#
#                   Description RasterType Resolution TemporalGranularity  \
# 123  Land Surface Reflectance       Tile        30m               Daily
# 124  Land Surface Reflectance       Tile        30m               Daily
#
#                                     DocLink   Source TemporalExtentStart  \
# 123  https://doi.org/10.5067/HLS/HLSS30.002  LP DAAC          2015-12-01
# 124  https://doi.org/10.5067/HLS/HLSL30.002  LP DAAC          2013-04-01
#
#     TemporalExtentEnd                                               Info
# 123           Present  {'provider_id': 'lp_prod', 'is_utm_zonal': Tru...
# 124           Present  {'provider_id': 'lp_prod', 'is_utm_zonal': Tru...

# %% [markdown]
# #### Using the info above, start a list of desired products by using the highest temporal resolution LAI product, `MCD15A3H.006`.

# %%
prods = list(filtered_products['ProductAndVersion'])

prods
# Out:
# ['HLSS30.020', 'HLSL30.020']

# %% [markdown]
# ***
# # 2b. Search and Explore Available Layers [[List Layers](https://appeears.earthdatacloud.nasa.gov/api/#list-layers)]
# #### The product API allows you to call all of the layers available for a given product. Each product is referenced by its `ProductAndVersion` property. For a list of the layer names only, print the keys from the dictionary below.

# %%
info_response = r.get('{}product/{}'.format(api, prods[0])).json()  # Request layers for the 2nd product (index 1) in the list: MOD11A2.061

# %%
print(list(info_response.keys()), sep='\t')
# Out:
# ['B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B09', 'B10', 'B11', 'B12', 'B8A', 'Fmask', 'SAA', 'SZA', 'VAA', 'VZA']

# %%
for name, info_values in info_response.items():

    desc = info_values['Description']
    s = (abs(len(name)-10) + len(desc))

    print(f'{name} {desc.rjust(s)}')
# Out:
# B01        B01 - Coastal Aerosol (0.43 – 0.45 µm)
# B02        B02 - Blue (0.45 – 0.51 µm)
# B03        B03 - Green (0.53 – 0.59 µm)
# B04        B04 - Red (0.64 – 0.67 µm)
# B05        B05 - Red Edge1 (0.69 – 0.71 µm)
# B06        B06 - Red Edge2 (0.73 – 0.75 µm)
# B07        B07 - Red Edge3 (0.77 – 0.79 µm)
# B08        B08 - NIR Broad (0.78 – 0.88 µm)
# B09        B09 - Water Vapor (0.93 – 0.95 µm)
# B10        B10 - Cirrus (1.36 – 1.38 µm)
# B11        B11 - SWIR1 (1.57 – 1.65 µm)
# B12        B12 - SWIR2 (2.11 – 2.29 µm)
# B8A        B8A - NIR Narrow (0.85 – 0.88 µm)
# Fmask      Quality Bits
# SAA        Sun Azimuth Angle
# SZA        Sun Zenith Angle
# VAA        View Azimuth Angle
# VZA        View Zenith Angle

# %%
item = 'B05'

# %% [markdown]
# #### AρρEEARS also allows subsetting data spectrally (by band). Create a tupled list with product name and specific layers desired.

# %%
layers = [(prods[0],'Fmask'),(prods[0],'SAA')]

product_layers = pd.DataFrame(layers, columns=['product', 'layer'])

# %% [markdown]
# #### Below, take the tupled list (layers) and create a list of dictionaries to store each layer+product combination. This will make it easier to insert into the json file used to submit a request in Section 3.

# %%
prodLayer = product_layers.to_dict('records')
prodLayer
# Out:
# [{'product': 'HLSS30.020', 'layer': 'Fmask'},
#  {'product': 'HLSS30.020', 'layer': 'SAA'}]

# %% [markdown]
# ***
# # 3. Submit an Area Request [[Tasks](https://appeears.earthdatacloud.nasa.gov/api/#tasks)]
# #### The **Submit task** API call provides a way to submit a new request to be processed. It can accept data via JSON, query string, or a combination of both. In the example below, compile a json and submit a request. Tasks in AρρEEARS correspond to each request associated with your user account. Therefore, each of the calls to this service requires an authentication token (see Section 1c.), which is stored in a header below.

# %%
token = token_response['token']                      # Save login token to a variable
head = {'Authorization': 'Bearer {}'.format(token)}  # Create a header to store token information, needed to submit a request

# %% [markdown]
# ---
# ## 3a. Import a Shapefile
# #### In this section, begin by importing a shapefile using the `geopandas` package. The shapefile is publically available for download from the [NPS website](https://irma.nps.gov/DataStore/Reference/Profile/2224545?lnv=True).

# %%
nps = gpd.read_file('{}nps_boundary.shp'.format(inDir + os.sep + 'Data' + os.sep)) # Read in shapefile as dataframe using geopandas

# %%
nps.shape
# Out:
# (419, 12)

# %%
nps.dtypes
# Out:
# UNIT_CODE             object
# GIS_Notes             object
# UNIT_NAME             object
# DATE_EDIT     datetime64[ms]
# STATE                 object
# REGION                object
# GNIS_ID               object
# UNIT_TYPE             object
# CREATED_BY            object
# METADATA              object
# PARKNAME              object
# geometry            geometry
# dtype: object

# %%
# transform DATE_EDIT to utc string format
nps['DATE_EDIT'] = nps['DATE_EDIT'].dt.strftime('%Y-%m-%d')

# %%
nps = nps[[
    'UNIT_CODE', 'UNIT_NAME', 'DATE_EDIT',
    'STATE', 'GNIS_ID', 'geometry'
]]

# %%
nps.head()
# Out:
#   UNIT_CODE                                   UNIT_NAME   DATE_EDIT STATE  \
# 0      AMME                      American Memorial Park  2015-04-22    MP
# 1      EBLA  Ebey's Landing National Historical Reserve  2015-04-22    WA
# 2      LARO     Lake Roosevelt National Recreation Area  2015-04-22    WA
# 3      LEWI    Lewis and Clark National Historical Park  2015-04-22    WA
# 4      OLYM                       Olympic National Park  2015-04-22    WA
#
#    GNIS_ID                                           geometry
# 0  1879026  POLYGON ((145.7235 15.22246, 145.72352 15.2223...
# 1  1888910  POLYGON ((-122.6529 48.25379, -122.62396 48.21...
# 2  1531834  MULTIPOLYGON (((-118.452 47.84213, -118.45201 ...
# 3  2055170  MULTIPOLYGON (((-124.07495 46.30228, -124.0746...
# 4  1530459  MULTIPOLYGON (((-124.38061 47.6021, -124.3807 ...

# %%
nps.tail()
# Out:
#     UNIT_CODE                                  UNIT_NAME   DATE_EDIT STATE  \
# 414      JAZZ  New Orleans Jazz National Historical Park  2017-11-08    LA
# 415      PETR               Petroglyph National Monument  2017-11-17    NM
# 416      REER       Reconstruction Era National Monument  2017-10-24    SC
# 417      FRRI           Freedom Riders National Monument  2017-10-24    AL
# 418      BICR  Birmingham Civil Rights National Monument  2017-10-24    AL
#
#      GNIS_ID                                           geometry
# 414  2035602  POLYGON ((-90.06794 29.96404, -90.0672 29.9635...
# 415   920404  MULTIPOLYGON (((-106.73768 35.15827, -106.7376...
# 416  2783288  MULTIPOLYGON (((-80.57853 32.38752, -80.57853 ...
# 417  2783290  MULTIPOLYGON (((-85.90731 33.63509, -85.90759 ...
# 418  2783289  POLYGON ((-86.81465 33.51514, -86.8148 33.5150...

# %% [markdown]
# #### Below, query the `geopandas` dataframe for the national park that you are interested in using for your region of interest, here *Grand Canyon National Park*.

# %%
gc = nps[
    nps['UNIT_NAME'].str.contains('Grand Canyon')
]

# %%
gc
# Out:
#     UNIT_CODE                   UNIT_NAME   DATE_EDIT STATE GNIS_ID  \
# 253      GRCA  Grand Canyon National Park  2014-04-15    AZ   23866
#
#                                               geometry
# 253  POLYGON ((-111.7042 36.70987, -111.7042 36.709...

# %%
# save nps_gs to a json file named like the UNIT_NAME value
filename = gc['UNIT_NAME'].values[0].replace(' ','_')

#save to file
gc.to_file(f'./{filename}.json', driver='GeoJSON')

# %%
nps_gc = json.loads(gc.to_json())

# %%
print(nps_gc['type'], '\n')

print(nps_gc['crs'], '\n')

print(nps_gc['features'][0].keys())
# Out:
# FeatureCollection
#
# {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:OGC::CRS83'}}
#
# dict_keys(['id', 'type', 'properties', 'geometry'])

# %%
print(nps_gc['features'][0]['id'], nps_gc['features'][0]['type'], '\n')

print(nps_gc['features'][0]['properties'], '\n')

print(nps_gc['features'][0]['geometry'].keys(), '\n')
# Out:
# 253 Feature
#
# {'UNIT_CODE': 'GRCA', 'UNIT_NAME': 'Grand Canyon National Park', 'DATE_EDIT': '2014-04-15', 'STATE': 'AZ', 'GNIS_ID': '23866'}
#
# dict_keys(['type', 'coordinates'])

# %% [markdown]
# ---
# ## 3b. Search and Explore Available Projections [[Spatial API](https://appeears.earthdatacloud.nasa.gov/api/#spatial)]
# #### The spatial API provides some helper services used to support submitting area task requests. The call below will retrieve the list of supported projections in AρρEEARS.

# %%
projections = r.get('{}spatial/proj'.format(api)).json()  # Call to spatial API, return projs as json

# %%
projections_df = pd.DataFrame(projections)

# %%
projections_df.dtypes
# Out:
# Name           object
# LongName       object
# Description    object
# Platforms      object
# Proj4          object
# Datum          object
# EPSG           object
# Units          object
# GridMapping    object
# Available        bool
# dtype: object

# %%
projections_df.columns
# Out:
# Index(['Name', 'LongName', 'Description', 'Platforms', 'Proj4', 'Datum',
#        'EPSG', 'Units', 'GridMapping', 'Available'],
#       dtype='object')

# %% [markdown]
# #### Create a dictionary of projections with projection `Name` as the keys.

# %%
projs = projections_df.set_index('Name', drop=False)     # Print dictionary keys


projs = projs[
    projs['Available'] == True

][[
    'Name',
    'LongName', 'Description', 'Platforms', 'Proj4',
    'Datum', 'EPSG', 'Units', 'GridMapping'
]]

# %%
projs.head(3)
# Out:
#                   Name           LongName Description  \
# Name
# native          native  Native Projection
# geographic  geographic         Geographic
# sinu_modis  sinu_modis   MODIS Sinusoidal
#
#                                                     Platforms  \
# Name
# native
# geographic  ['SRTM', 'ECOSTRESS', 'SSEBop ET', 'GPW', 'AST...
# sinu_modis  ['Combined MODIS', 'Terra MODIS', 'Aqua MODIS'...
#
#                                                         Proj4  Datum    EPSG  \
# Name
# native
# geographic           +proj=longlat +datum=WGS84 +no_defs=True  wgs84  4326.0
# sinu_modis  +proj=sinu +lon_0=0 +x_0=0 +y_0=0 +R=6371007.1...
#
#               Units         GridMapping
# Name
# native
# geographic  degrees  latitude_longitude
# sinu_modis   meters          sinusoidal

# %%
projs.tail(2)
# Out:
#                                 Name                           LongName  \
# Name
# easegrid_2_global  easegrid_2_global               EASE-Grid 2.0 Global
# easegrid_2_north    easegrid_2_north  EASE-Grid 2.0 Northern Hemisphere
#
#                   Description Platforms  \
# Name
# easegrid_2_global              ['SMAP']
# easegrid_2_north               ['SMAP']
#
#                                                                Proj4  Datum  \
# Name
# easegrid_2_global  +proj=cea +lon_0=0 +lat_ts=30 +x_0=0 +y_0=0 +d...  wgs84
# easegrid_2_north   +proj=laea +lat_0=90 +lon_0=0 +x_0=0 +y_0=0 +d...  wgs84
#
#                      EPSG   Units                     GridMapping
# Name
# easegrid_2_global  6933.0  meters  lambert_cylindrical_equal_area
# easegrid_2_north   6931.0  meters  lambert_cylindrical_equal_area

# %%
projs_dict = projs.to_dict('index')

# %% [markdown]
# #### Print the information for the projection used in this tutorial.

# %%
projs_dict['geographic']
# Out:
# {'Name': 'geographic',
#  'LongName': 'Geographic',
#  'Description': '',
#  'Platforms': "['SRTM', 'ECOSTRESS', 'SSEBop ET', 'GPW', 'ASTER GDEM', 'NASADEM', 'MEaSUREs LSTE', 'EMIT']",
#  'Proj4': '+proj=longlat +datum=WGS84 +no_defs=True',
#  'Datum': 'wgs84',
#  'EPSG': 4326.0,
#  'Units': 'degrees',
#  'GridMapping': 'latitude_longitude'}

# %% [markdown]
# ---
# ## 3c. Compile a JSON  [[Task Object](https://appeears.earthdatacloud.nasa.gov/api/#task-object)]
# #### In this section, begin by setting up the information needed to compile an acceptable json for submitting an AρρEEARS area request. For detailed information on required json parameters, see the [API Documentation](https://appeears.earthdatacloud.nasa.gov/api/).

# %%
task_type = ['point','area']            # Type of task, area or point
proj = projs_dict['geographic']['Name'] # Set output projection
outFormat = ['geotiff', 'netcdf4']      # Set output file format type
startDate = '07-01-2017'                # Start of the date range for which to extract data: MM-DD-YYYY
endDate = '07-31-2017'                  # End of the date range for which to extract data: MM-DD-YYYY
recurring = False                       # Specify True for a recurring date range
#yearRange = [2000,2016]                # if recurring = True, set yearRange, change start/end date to MM-DD

# %%
def format_date_yyyymmdd(date_str):
    return time.strftime('%Y%m%d', time.strptime(date_str, '%m-%d-%Y'))

# %%
task_name = '_'.join([
    prodLayer[0]['product'],
    format_date_yyyymmdd(startDate),
    'to',
    format_date_yyyymmdd(endDate)
])
task_name
# Out:
# 'HLSS30.020_20170701_to_20170731'

# %% [markdown]
# #### Below, compile the JSON to be submitted as an area request. Notice that `nps_gc` is inserted from the shapefile transformed to a json via the `geopandas` and `json` packages above in section 3a.

# %%
task = {
    'task_type': task_type[1],
    'task_name': task_name,
    'params': {
         'dates': [
         {
             'startDate': startDate,
             'endDate': endDate
         }],
         'layers': prodLayer,
         'output': {
                 'format': { 'type': outFormat[0] },
                         'projection': proj},
         'geo': nps_gc,
    }
}

# %% [markdown]
# ***
# ## 3d. Submit a Task Request [[Submit Task](https://appeears.earthdatacloud.nasa.gov/api/#submit-task)]
# #### Below, post a call to the API task service, using the `task` json created above.

# %%
# Post json to the API task service, return response as json
task_response = r.post('{}task'.format(api), json=task, headers=head)

# %%
task_response.json()
# Out:
# {'task_id': 'bb803546-d5ac-401c-a377-f16802c692f2', 'status': 'pending'}

# %% [markdown]
# ***
# ## 3e. Retrieve Task Status [[Retrieve Task](https://appeears.earthdatacloud.nasa.gov/api/#retrieve-task)]
# #### This API call will list all of the requests associated with your user account, automatically sorted by date descending with the most recent requests listed first.

# %% [markdown]
# #### The AρρEEARS API contains some helpful formatting resources. Below, limit the API response to 2 entries and set `pretty` to True to format the response as an organized json, making it easier to read. Additional information on AρρEEARS API [pagination](https://appeears.earthdatacloud.nasa.gov/api/#pagination) and [formatting](https://appeears.earthdatacloud.nasa.gov/api/#formatting) can be found in the API documentation.

# %%
params = {'limit': 1, 'pretty': True} # Limit API response to 2 most recent entries, return as pretty json

# %%
# Query task service, setting params and header
tasks_response = r.get('{}task'.format(api), params=params, headers=head).json()

# Print tasks response
tasks_response
# Out:
# [{'tier': 2,
#   'error': None,
#   'params': {'dates': [{'endDate': '07-31-2017', 'startDate': '07-01-2017'}],
#    'layers': [{'layer': 'Fmask', 'product': 'HLSS30.020'},
#     {'layer': 'SAA', 'product': 'HLSS30.020'}],
#    'output': {'format': {'type': 'geotiff'}, 'projection': 'geographic'}},
#   'status': 'processing',
#   'created': '2024-10-01T23:53:49.206180',
#   'task_id': 'bb803546-d5ac-401c-a377-f16802c692f2',
#   'updated': '2024-10-01T23:54:04.919578',
#   'user_id': 'marthoxx@gmail.com',
#   'estimate': {'request_size': 3418322138.764077, 'request_memory': 1},
#   'retry_at': None,
#   'has_swath': False,
#   'task_name': 'space-apps-geo-tool',
#   'task_type': 'area',
#   'api_version': 'v1',
#   'svc_version': '3.63',
#   'web_version': None,
#   'has_nsidc_daac': False,
#   'expires_on': '2024-10-31T23:54:04.919578'}]

# %% [markdown]
# #### Next, take the task id returned from the `task_response` that was generated when submitting your request, and use the AρρEEARS API status service to check the status of your request.

# %%
task_id = tasks_response[0]['task_id']                                               # Set task id from request submission
status_response = r.get('{}status/{}'.format(api, task_id), headers=head).json() # Call status service with specific task ID & user credentials
status_response
# Out:
# {'task_id': 'bb803546-d5ac-401c-a377-f16802c692f2',
#  'updated': '2024-10-01T23:54:27.621615',
#  'user_id': 'marthoxx@gmail.com',
#  'progress': {'details': [{'desc': 'Initializing',
#     'step': 1,
#     'pct_complete': 0},
#    {'desc': 'Downloading', 'step': 2, 'pct_complete': 0},
#    {'desc': 'Subsetting', 'step': 3, 'pct_complete': 0},
#    {'desc': 'Generating Files', 'step': 4, 'pct_complete': 0},
#    {'desc': 'Extracting Stats', 'step': 5, 'pct_complete': 0},
#    {'desc': 'Finalizing', 'step': 6, 'pct_complete': 0}],
#   'summary': 0,
#   'user_consider_limit': True},
#  'has_swath': False,
#  'status_id': '0c5c9c50-dd75-4522-a425-48b37799c6c3',
#  'status_type': 'task'}

# %% [markdown]
# #### Above, if your request is still processing, you can find information on the status of how close it is to completing.
# #### Below, call the task service for your request every 20 seconds to check the status of your request.

# %%
# Ping API until request is complete, then continue to Section 4
starttime = time.time()

status = lambda: r.get('{}task/{}'.format(api, task_id), headers=head).json()['status']

while status() != 'done':
    print(status())
    if(status() != 'done'):
        time.sleep(60.0 - ((time.time() - starttime) % 60.0))
# Out:
# processing
# processing
# processing
# processing
# processing
# processing

# %% [markdown]
# ***
# # 4. Download a Request [[Bundle API](https://appeears.earthdatacloud.nasa.gov/api/#bundle)]
# #### Before downloading the request output, set up an output directory to store the output files, and examine the files contained in the request output.

# %%
destDir = os.path.join(inDir, task_name)                # Set up output directory using input directory and task name
if not os.path.exists(destDir):os.makedirs(destDir)     # Create the output directory

# %% [markdown]
# ---
# ## 4a. Explore Files in Request Output [[List Files](https://appeears.earthdatacloud.nasa.gov/api/#list-files)]
# #### The bundle API provides information about completed tasks. For any completed task, a bundle can be queried to return the files contained as a part of the task request. Below, call the bundle API and return all of the output files.

# %%
bundle = r.get('{}bundle/{}'.format(api,task_id), headers=head).json()  # Call API and return bundle contents for the task_id as json
bundle                                                    # Print bundle contents
# Out:
# {'files': [{'sha256': '28dc651d603782e8dc0b882fe5963ba0dd2fff239994b35529621a86c043c7fb',
#    'file_id': '6fada98b-fbec-44ed-a7c1-6c8c7cefa715',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017185_aid0001_12N.tif',
#    'file_size': 66618,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017185_aid0001_12N.tif'},
#   {'sha256': 'd69ca3450f65b0741e31b89c76a198bf6f21758a3c90eb900108a140234c28ef',
#    'file_id': 'ed11b5d1-9579-415b-aff0-d41dc41aa296',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017191_aid0001_11N.tif',
#    'file_size': 195331,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017191_aid0001_11N.tif'},
#   {'sha256': '3739f52ea4eb6f946940a957bb0782464a771aa25cf809d2bf112b314df41e9e',
#    'file_id': 'b71bab87-b89a-490b-a253-d48097754484',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017191_aid0001_12N.tif',
#    'file_size': 485300,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017191_aid0001_12N.tif'},
#   {'sha256': '3ca432479e4dfe806745f2b9c73b6bf64ca4f874c95005a8ce081a1fcb748857',
#    'file_id': '01a82192-ee91-49c9-898f-fcd19a8a4750',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017193_aid0001_11N.tif',
#    'file_size': 201894,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017193_aid0001_11N.tif'},
#   {'sha256': '7bfc0be9ee31f9860ea7e06d05ce4355a68456e09320daf1e99ba61500a84255',
#    'file_id': '80543391-a62d-401f-9a14-943903d22b67',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017193_aid0001_12N.tif',
#    'file_size': 1050796,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017193_aid0001_12N.tif'},
#   {'sha256': '5af60faef4ae4cd4e9146fdd00456b43f8bff88d51a1d028c59f76a6599449e3',
#    'file_id': 'f0c5cd91-e098-415d-a0d2-16532db9a9f1',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017196_aid0001_11N.tif',
#    'file_size': 150444,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017196_aid0001_11N.tif'},
#   {'sha256': '85d3f4568f788149b2f247677deb87bb3e78760caee615e432cb83f7bc928f3e',
#    'file_id': 'c07bff34-2b2c-4c39-995a-b6022f731c58',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017196_aid0001_12N.tif',
#    'file_size': 442464,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017196_aid0001_12N.tif'},
#   {'sha256': '618d9e665523acc00c8e96ae0dbe0eefcac4e6e20dce703a04aa01e779d80e58',
#    'file_id': '4ae56243-eca2-49a3-9d75-197688e43553',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017198_aid0001_11N.tif',
#    'file_size': 206090,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017198_aid0001_11N.tif'},
#   {'sha256': 'b5a6ef9a6297dc61a3db30f8bf2173b5bb2727e721adbac300cf5670eda4faf7',
#    'file_id': 'a65465c4-ee9e-4311-8c61-8e4f06564a7b',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017198_aid0001_12N.tif',
#    'file_size': 1104891,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017198_aid0001_12N.tif'},
#   {'sha256': '28dc651d603782e8dc0b882fe5963ba0dd2fff239994b35529621a86c043c7fb',
#    'file_id': '8803ef68-b672-4820-b04f-3373ce9b5877',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017200_aid0001_12N.tif',
#    'file_size': 66618,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017200_aid0001_12N.tif'},
#   {'sha256': '5d8361c0607b3213839ab3c9900959a0fa75d1065aa7c19d1cdd20bbdb133cf6',
#    'file_id': 'e1a55298-67d0-4c93-a56f-5f45a4b5d627',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017201_aid0001_11N.tif',
#    'file_size': 278405,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017201_aid0001_11N.tif'},
#   {'sha256': '02c63547731ac2d4c9f2d816acd5c03adf3abd88787e2ea7c3662cacd9e11460',
#    'file_id': '69969a50-f097-4ac1-92af-be18c6e245a6',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017201_aid0001_12N.tif',
#    'file_size': 662128,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017201_aid0001_12N.tif'},
#   {'sha256': '28dc651d603782e8dc0b882fe5963ba0dd2fff239994b35529621a86c043c7fb',
#    'file_id': 'ecb00c9e-84a9-476a-b650-6a45aca6e6d4',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017205_aid0001_12N.tif',
#    'file_size': 66618,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017205_aid0001_12N.tif'},
#   {'sha256': 'b0c9a8487c1fe46103a04cde794009ead637d160c4d0482c5a675da73baa9641',
#    'file_id': '78d89c56-9241-4040-8f24-deed590981d4',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017206_aid0001_12N.tif',
#    'file_size': 54887,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017206_aid0001_12N.tif'},
#   {'sha256': '0723de3a1621c15c159e1e1db878458fc7b61a66b78e0174523e16c7efa81b8a',
#    'file_id': '7efb619e-1bf7-46c6-9bc1-2d280862db3f',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017211_aid0001_11N.tif',
#    'file_size': 247336,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017211_aid0001_11N.tif'},
#   {'sha256': '2ff6e1f2c03f8d151ee6403a8572add8e62e3d5dec022b2518740475fdf5f807',
#    'file_id': '6001e0ca-9884-41ab-b119-2206fb00c890',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017211_aid0001_12N.tif',
#    'file_size': 608063,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017211_aid0001_12N.tif'},
#   {'sha256': 'bec30976553c7f23b64a2b430bf6b8a35e9077d7c41b3404749eb6554b0dc74b',
#    'file_id': '0c9aecbc-b596-4c61-bccc-d9e599dd0d94',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017185_aid0001_12N.tif',
#    'file_size': 562386,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017185_aid0001_12N.tif'},
#   {'sha256': 'e4e5160d0e37301d66f6d963df92664a14fc559731c8d56234f3fef04962e6cc',
#    'file_id': 'c9e15a82-9348-42ac-a4c1-8bc7c0ee3ca7',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017191_aid0001_11N.tif',
#    'file_size': 411439,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017191_aid0001_11N.tif'},
#   {'sha256': 'a4d2dd900448b876627ecc802edf94a615aed0d74f40066195a071c247c141dd',
#    'file_id': '5f3f5d67-5830-4b19-afec-ae8722f1e396',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017191_aid0001_12N.tif',
#    'file_size': 2060778,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017191_aid0001_12N.tif'},
#   {'sha256': '64b2c770726f26a7b48df8f7cec2b77d8e3d695891fdc75abcfca58acd553e72',
#    'file_id': '22f2828b-a5c8-44b2-942d-6e0a16ebedc5',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017193_aid0001_11N.tif',
#    'file_size': 389869,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017193_aid0001_11N.tif'},
#   {'sha256': 'bc0a30655554462877a3b0388964cbbf05e2312aeb4e28a82fdca0e28050e095',
#    'file_id': 'fd8633cb-6f66-4533-a6b4-262c3ad31e6d',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017193_aid0001_12N.tif',
#    'file_size': 2344953,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017193_aid0001_12N.tif'},
#   {'sha256': '6e34b9fe8ae45969bf12d6d7f23ac815ecca03f6d621a1da3810177a9e3b7bf9',
#    'file_id': 'a417822a-31e5-474d-88c7-823c520a0892',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017196_aid0001_11N.tif',
#    'file_size': 409339,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017196_aid0001_11N.tif'},
#   {'sha256': '52aaad6753e3a96423ceff4a46637fcad0fb2b43923cd627cbf1759166fe4f8d',
#    'file_id': '5f67090f-95a3-480e-a25c-9a061b99203f',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017196_aid0001_12N.tif',
#    'file_size': 2037843,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017196_aid0001_12N.tif'},
#   {'sha256': '50926fd34416cf838d68bfe005225d103c5663c50f0c7cfe801a2e53e8098622',
#    'file_id': 'a6328976-5e04-42be-aac6-ddd2932ff20a',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017198_aid0001_11N.tif',
#    'file_size': 387338,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017198_aid0001_11N.tif'},
#   {'sha256': 'ada0573280d08bf0a912e9110ff8ac04c8340fe159e7abe46db86efe9a0611ae',
#    'file_id': '1fd67481-71a7-405f-b3b1-936d5b7852fc',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017198_aid0001_12N.tif',
#    'file_size': 2328018,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017198_aid0001_12N.tif'},
#   {'sha256': '2ac57edac2068fbe222710892ce993380182ca7b6e2d0b66a46203fee97a63f5',
#    'file_id': '7f917cf7-4eb0-46c5-a674-2a4d79605d82',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017200_aid0001_12N.tif',
#    'file_size': 556436,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017200_aid0001_12N.tif'},
#   {'sha256': '250cee69dc2ff05f76357f5df1e95f37c067b954e32f55ad4d93f8936c7ec2ce',
#    'file_id': '0dceb4e0-aac9-4060-ab36-104c2f6a13fe',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017201_aid0001_11N.tif',
#    'file_size': 407205,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017201_aid0001_11N.tif'},
#   {'sha256': 'd257701be29e6e7ddd0f96cf562fd4f7855f511fa5333cbdec94e49b40a21207',
#    'file_id': '202a2c85-6969-4b7e-bacf-27e3c7ec70e8',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017201_aid0001_12N.tif',
#    'file_size': 2024580,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017201_aid0001_12N.tif'},
#   {'sha256': '2c95250c39eef9147ad6a42ea37220c2d596207cf5e3eb30903d48db4cea4906',
#    'file_id': 'c9f4edda-a716-4186-b95b-11e7258d09bc',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017205_aid0001_12N.tif',
#    'file_size': 556563,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017205_aid0001_12N.tif'},
#   {'sha256': 'c18613cbbbc756ca6d1d3206c17566302533e9d4c0d272974e8ae6dad9f16b75',
#    'file_id': '3e720d21-46d7-4973-a4d2-8747a72eabcc',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017206_aid0001_12N.tif',
#    'file_size': 259958,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017206_aid0001_12N.tif'},
#   {'sha256': '8ceb83f02e35688765bd10643d3e0ea62f13aa41db11f0a3580021193d943574',
#    'file_id': '2efd7ce3-8fea-4171-9a75-e167b7dc6949',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017211_aid0001_11N.tif',
#    'file_size': 400587,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017211_aid0001_11N.tif'},
#   {'sha256': 'f7ede082fe1d2b751f1ce74ac179db1d4d624d1345c1fca0403e3ae37d0083f0',
#    'file_id': '424cebc2-5305-4234-ab37-3b6afd6caf09',
#    'file_name': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017211_aid0001_12N.tif',
#    'file_size': 1977881,
#    'file_type': 'tif',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017211_aid0001_12N.tif'},
#   {'sha256': '8d5ee4d2ceeab42ea46c72a1dd11b81667c86571508c8226363fa0619a4beaae',
#    'file_id': '77d52931-8096-4ddf-8b0b-46eda6936f34',
#    'file_name': 'HLSS30-020-Fmask-lookup.csv',
#    'file_size': 2548,
#    'file_type': 'csv',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30-020-Fmask-lookup.csv'},
#   {'sha256': '82fa96738de9843ad4964fb3986955b4d1e3c9859b789b83093737300df38a71',
#    'file_id': '64e64388-658e-4e4b-94d1-908f0d1699af',
#    'file_name': 'HLSS30-020-Fmask-Statistics-QA.csv',
#    'file_size': 3647,
#    'file_type': 'csv',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30-020-Fmask-Statistics-QA.csv'},
#   {'sha256': 'cec95cba405df509a6941b081923a0548cec4f09f345eaf33ed2d5999e29ff31',
#    'file_id': '005874ec-e7f1-47a2-b37a-f301daef668b',
#    'file_name': 'HLSS30-020-Statistics.csv',
#    'file_size': 2863,
#    'file_type': 'csv',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/HLSS30-020-Statistics.csv'},
#   {'sha256': '9329ad187dbcfaf7aab4b5f847c02eea7a611d0486db294201d9befc35cd243b',
#    'file_id': '77d0700d-9324-4281-9bed-995e65fa8445',
#    'file_name': 'space-apps-geo-tool-granule-list.txt',
#    'file_size': 14288,
#    'file_type': 'txt',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/space-apps-geo-tool-granule-list.txt'},
#   {'sha256': '0ad561a373fc2cb6041c416f3b9c0437d9c3833613bf88c26603b94d16419242',
#    'file_id': 'a1cbc07a-e787-4a8a-8a59-37e5ea9aaea0',
#    'file_name': 'space-apps-geo-tool-request.json',
#    'file_size': 13613779,
#    'file_type': 'json',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/space-apps-geo-tool-request.json'},
#   {'sha256': 'eb3e70254bcd837a6366a8b4f226a454f53389fff276a58a366be5f3ddf36daf',
#    'file_id': '82fbacbd-d0c7-4f6d-a6ad-b3ac188eca30',
#    'file_name': 'space-apps-geo-tool-HLSS30-020-metadata.xml',
#    'file_size': 22213,
#    'file_type': 'xml',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/space-apps-geo-tool-HLSS30-020-metadata.xml'},
#   {'sha256': '8f8c960831fd96abae87b943ed4b8fe0bc0b2df4995f5a251dcb31fbda639d2a',
#    'file_id': '5225b64d-2007-477a-a8c4-a79d4049007b',
#    'file_name': 'README.md',
#    'file_size': 37802,
#    'file_type': 'txt',
#    's3_url': 's3://appeears-output/bb803546-d5ac-401c-a377-f16802c692f2/README.md'}],
#  'created': '2024-10-01T23:54:12.674564',
#  'task_id': 'bb803546-d5ac-401c-a377-f16802c692f2',
#  'updated': '2024-10-02T00:00:05.519702',
#  'bundle_type': 'area'}

# %% [markdown]
# ***
# ## 4b. Download Files in a Request (Automation) [[Download File](https://appeears.earthdatacloud.nasa.gov/api/#download-file)]
# #### Now, use the contents of the bundle to select the file name and id and store as a dictionary.

# %%
files = {}                                                       # Create empty dictionary
for f in bundle['files']: files[f['file_id']] = f['file_name']   # Fill dictionary with file_id as keys and file_name as values
files
# Out:
# {'6fada98b-fbec-44ed-a7c1-6c8c7cefa715': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017185_aid0001_12N.tif',
#  'ed11b5d1-9579-415b-aff0-d41dc41aa296': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017191_aid0001_11N.tif',
#  'b71bab87-b89a-490b-a253-d48097754484': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017191_aid0001_12N.tif',
#  '01a82192-ee91-49c9-898f-fcd19a8a4750': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017193_aid0001_11N.tif',
#  '80543391-a62d-401f-9a14-943903d22b67': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017193_aid0001_12N.tif',
#  'f0c5cd91-e098-415d-a0d2-16532db9a9f1': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017196_aid0001_11N.tif',
#  'c07bff34-2b2c-4c39-995a-b6022f731c58': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017196_aid0001_12N.tif',
#  '4ae56243-eca2-49a3-9d75-197688e43553': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017198_aid0001_11N.tif',
#  'a65465c4-ee9e-4311-8c61-8e4f06564a7b': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017198_aid0001_12N.tif',
#  '8803ef68-b672-4820-b04f-3373ce9b5877': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017200_aid0001_12N.tif',
#  'e1a55298-67d0-4c93-a56f-5f45a4b5d627': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017201_aid0001_11N.tif',
#  '69969a50-f097-4ac1-92af-be18c6e245a6': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017201_aid0001_12N.tif',
#  'ecb00c9e-84a9-476a-b650-6a45aca6e6d4': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017205_aid0001_12N.tif',
#  '78d89c56-9241-4040-8f24-deed590981d4': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017206_aid0001_12N.tif',
#  '7efb619e-1bf7-46c6-9bc1-2d280862db3f': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017211_aid0001_11N.tif',
#  '6001e0ca-9884-41ab-b119-2206fb00c890': 'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017211_aid0001_12N.tif',
#  '0c9aecbc-b596-4c61-bccc-d9e599dd0d94': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017185_aid0001_12N.tif',
#  'c9e15a82-9348-42ac-a4c1-8bc7c0ee3ca7': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017191_aid0001_11N.tif',
#  '5f3f5d67-5830-4b19-afec-ae8722f1e396': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017191_aid0001_12N.tif',
#  '22f2828b-a5c8-44b2-942d-6e0a16ebedc5': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017193_aid0001_11N.tif',
#  'fd8633cb-6f66-4533-a6b4-262c3ad31e6d': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017193_aid0001_12N.tif',
#  'a417822a-31e5-474d-88c7-823c520a0892': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017196_aid0001_11N.tif',
#  '5f67090f-95a3-480e-a25c-9a061b99203f': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017196_aid0001_12N.tif',
#  'a6328976-5e04-42be-aac6-ddd2932ff20a': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017198_aid0001_11N.tif',
#  '1fd67481-71a7-405f-b3b1-936d5b7852fc': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017198_aid0001_12N.tif',
#  '7f917cf7-4eb0-46c5-a674-2a4d79605d82': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017200_aid0001_12N.tif',
#  '0dceb4e0-aac9-4060-ab36-104c2f6a13fe': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017201_aid0001_11N.tif',
#  '202a2c85-6969-4b7e-bacf-27e3c7ec70e8': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017201_aid0001_12N.tif',
#  'c9f4edda-a716-4186-b95b-11e7258d09bc': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017205_aid0001_12N.tif',
#  '3e720d21-46d7-4973-a4d2-8747a72eabcc': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017206_aid0001_12N.tif',
#  '2efd7ce3-8fea-4171-9a75-e167b7dc6949': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017211_aid0001_11N.tif',
#  '424cebc2-5305-4234-ab37-3b6afd6caf09': 'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017211_aid0001_12N.tif',
#  '77d52931-8096-4ddf-8b0b-46eda6936f34': 'HLSS30-020-Fmask-lookup.csv',
#  '64e64388-658e-4e4b-94d1-908f0d1699af': 'HLSS30-020-Fmask-Statistics-QA.csv',
#  '005874ec-e7f1-47a2-b37a-f301daef668b': 'HLSS30-020-Statistics.csv',
#  '77d0700d-9324-4281-9bed-995e65fa8445': 'space-apps-geo-tool-granule-list.txt',
#  'a1cbc07a-e787-4a8a-8a59-37e5ea9aaea0': 'space-apps-geo-tool-request.json',
#  '82fbacbd-d0c7-4f6d-a6ad-b3ac188eca30': 'space-apps-geo-tool-HLSS30-020-metadata.xml',
#  '5225b64d-2007-477a-a8c4-a79d4049007b': 'README.md'}

# %% [markdown]
# #### Use the `files` dictionary and a `for` loop to automate downloading all of the output files into the output directory.

# %%
for f in files:
    dl = r.get('{}bundle/{}/{}'.format(api, task_id, f), headers=head, stream=True, allow_redirects = 'True')                                # Get a stream to the bundle file
    if files[f].endswith('.tif'):
        filename = files[f].split('/')[1]
    else:
        filename = files[f]
    filepath = os.path.join(destDir, filename)                                                       # Create output file path
    with open(filepath, 'wb') as f:                                                                  # Write file to dest dir
        for data in dl.iter_content(chunk_size=8192): f.write(data)
print('Downloaded files can be found at: {}'.format(destDir))
# Out:
# Downloaded files can be found at: ./HLSS30.020_20170701_to_20170731

# %%
#!zip -r HLSS30.020_20170701_to_20170731.zip HLSS30.020_20170701_to_20170731/

# %%
#!cp -r HLSS30.020_20170701_to_20170731.zip "/content/drive/MyDrive/Colab Notebooks/AppEEARS_API/HLSS30.020_20170701_to_20170731.zip"

# %% [markdown]
# ***
# # 5. Explore AρρEEARS Quality Service [[Quality API](https://appeears.earthdatacloud.nasa.gov/api/#quality)]
# #### The quality API provides quality details about all of the data products available in AρρEEARS. Below are examples of how to query the quality API for listing quality products, layers, and values. The final example (Section 5c.) demonstrates how AρρEEARS quality services can be leveraged to decode pertinent quality values for your data.
# #### First, reset pagination to include `offset` which allows you to set the number of results to skip before starting to return entries. Next, make a call to list all of the data product layers and the associated quality product and layer information.

# %%
# Limit response to 6 entries, start w/ 20th entry, return pretty json
params = {'limit': 6, 'pretty': True, 'offset': 20}

# Call quality API using pagination and return json
quality_response = r.get('{}quality'.format(api), params=params).json()

# Print response
quality_response
# Out:
# [{'ProductAndVersion': 'L07.002',
#   'Layer': 'SR_ATMOS_OPACITY',
#   'QualityProductAndVersion': 'L07.002',
#   'QualityLayers': ['QA_LINEAGE', 'QA_PIXEL', 'QA_RADSAT', 'SR_CLOUD_QA'],
#   'Continuous': False,
#   'VisibleToWorker': True},
#  {'ProductAndVersion': 'L08.002',
#   'Layer': 'SR_B1',
#   'QualityProductAndVersion': 'L08.002',
#   'QualityLayers': ['QA_LINEAGE', 'QA_PIXEL', 'QA_RADSAT', 'SR_QA_AEROSOL'],
#   'Continuous': False,
#   'VisibleToWorker': True},
#  {'ProductAndVersion': 'L08.002',
#   'Layer': 'SR_B2',
#   'QualityProductAndVersion': 'L08.002',
#   'QualityLayers': ['QA_LINEAGE', 'QA_PIXEL', 'QA_RADSAT', 'SR_QA_AEROSOL'],
#   'Continuous': False,
#   'VisibleToWorker': True},
#  {'ProductAndVersion': 'L08.002',
#   'Layer': 'SR_B3',
#   'QualityProductAndVersion': 'L08.002',
#   'QualityLayers': ['QA_LINEAGE', 'QA_PIXEL', 'QA_RADSAT', 'SR_QA_AEROSOL'],
#   'Continuous': False,
#   'VisibleToWorker': True},
#  {'ProductAndVersion': 'L08.002',
#   'Layer': 'SR_B4',
#   'QualityProductAndVersion': 'L08.002',
#   'QualityLayers': ['QA_LINEAGE', 'QA_PIXEL', 'QA_RADSAT', 'SR_QA_AEROSOL'],
#   'Continuous': False,
#   'VisibleToWorker': True},
#  {'ProductAndVersion': 'L08.002',
#   'Layer': 'SR_B5',
#   'QualityProductAndVersion': 'L08.002',
#   'QualityLayers': ['QA_LINEAGE', 'QA_PIXEL', 'QA_RADSAT', 'SR_QA_AEROSOL'],
#   'Continuous': False,
#   'VisibleToWorker': True}]

# %%
quality_response_df = pd.DataFrame(quality_response)
quality_response_df
# Out:
#   ProductAndVersion             Layer QualityProductAndVersion  \
# 0           L07.002  SR_ATMOS_OPACITY                  L07.002
# 1           L08.002             SR_B1                  L08.002
# 2           L08.002             SR_B2                  L08.002
# 3           L08.002             SR_B3                  L08.002
# 4           L08.002             SR_B4                  L08.002
# 5           L08.002             SR_B5                  L08.002
#
#                                       QualityLayers  Continuous  \
# 0    [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_CLOUD_QA]       False
# 1  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]       False
# 2  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]       False
# 3  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]       False
# 4  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]       False
# 5  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]       False
#
#    VisibleToWorker
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True

# %%
quality_response_df['ProductAndVersion']
# Out:
# 0    L07.002
# 1    L08.002
# 2    L08.002
# 3    L08.002
# 4    L08.002
# 5    L08.002
# Name: ProductAndVersion, dtype: object

# %% [markdown]
# ---
# ## 5a. List Quality Layers [[List Quality Layers](https://appeears.earthdatacloud.nasa.gov/api/#list-quality-layers)]
# #### This API call will list all of the quality layer information for a product.

# %%
product = 'L07.002'                                             # Product used in the example
ql_response = r.get('{}quality/{}'.format(api,product)).json()  # Call API to retrieve quality layers for selected product
pd.DataFrame(ql_response)                                                   # Print response
# Out:
#   ProductAndVersion             Layer QualityProductAndVersion  \
# 0           L07.002             SR_B1                  L07.002
# 1           L07.002             SR_B2                  L07.002
# 2           L07.002             SR_B3                  L07.002
# 3           L07.002             SR_B4                  L07.002
# 4           L07.002             SR_B5                  L07.002
# 5           L07.002             SR_B7                  L07.002
# 6           L07.002  SR_ATMOS_OPACITY                  L07.002
#
#                                     QualityLayers  VisibleToWorker
# 0  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_CLOUD_QA]             True
# 1  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_CLOUD_QA]             True
# 2  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_CLOUD_QA]             True
# 3  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_CLOUD_QA]             True
# 4  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_CLOUD_QA]             True
# 5  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_CLOUD_QA]             True
# 6  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_CLOUD_QA]             True

# %%
product = 'L08.002'                                             # Product used in the example
ql_response = r.get('{}quality/{}'.format(api,product)).json()  # Call API to retrieve quality layers for selected product
pd.DataFrame(ql_response)
# Out:
#   ProductAndVersion  Layer QualityProductAndVersion  \
# 0           L08.002  SR_B1                  L08.002
# 1           L08.002  SR_B2                  L08.002
# 2           L08.002  SR_B3                  L08.002
# 3           L08.002  SR_B4                  L08.002
# 4           L08.002  SR_B5                  L08.002
# 5           L08.002  SR_B6                  L08.002
# 6           L08.002  SR_B7                  L08.002
#
#                                       QualityLayers  VisibleToWorker
# 0  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]             True
# 1  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]             True
# 2  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]             True
# 3  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]             True
# 4  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]             True
# 5  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]             True
# 6  [QA_LINEAGE, QA_PIXEL, QA_RADSAT, SR_QA_AEROSOL]             True

# %% [markdown]
# ---
# ## 5b. Show Quality Values [[List Quality Values](https://appeears.earthdatacloud.nasa.gov/api/#list-quality-values)]
# #### This API call will list all of the values for a given quality layer.

# %%
qlayer = ql_response[1]['QualityLayers'][0]
qlayer
# Out:
# 'QA_LINEAGE'

# %%
qlayer = ql_response[1]['QualityLayers'][0]                                # Set quality layer from ql_response for 'Lai_500m'
qv_response = r.get('{}quality/{}/{}'.format(api, product, qlayer)).json() # Call API for list of bit-word quality values
qv_response                                                                # Print response
# Out:
# [{'ProductAndVersion': 'L08.002',
#   'QualityLayer': 'QA_LINEAGE',
#   'Name': 'Fill',
#   'Value': 0,
#   'Description': 'Fill pixel',
#   'Acceptable': None},
#  {'ProductAndVersion': 'L08.002',
#   'QualityLayer': 'QA_LINEAGE',
#   'Name': 'Fill',
#   'Value': 1,
#   'Description': 'pixel corresponds to scene 1',
#   'Acceptable': None},
#  {'ProductAndVersion': 'L08.002',
#   'QualityLayer': 'QA_LINEAGE',
#   'Name': 'Fill',
#   'Value': 2,
#   'Description': 'pixel corresponds to scene 2',
#   'Acceptable': None},
#  {'ProductAndVersion': 'L08.002',
#   'QualityLayer': 'QA_LINEAGE',
#   'Name': 'Fill',
#   'Value': 3,
#   'Description': 'pixel corresponds to scene 3',
#   'Acceptable': None}]

# %% [markdown]
# ---
# ## 5c. Decode Quality Values [[Decode Quality Values](https://appeears.earthdatacloud.nasa.gov/api/#decode-quality-values)]
# #### This API call will decode the bits for a given quality value.

# %%
val = 1                                                                            # Set a specific value
q_response = r.get('{}quality/{}/{}/{}'.format(api, product, qlayer, val)).json()  # Call quality API for specific value
q_response                                                                         # Print response
# Out:
# {'Binary Representation': '0b00000001',
#  'Fill': {'bits': '0b01', 'description': 'pixel corresponds to scene 1'}}

# %% [markdown]
# ***
# # 6. BONUS: Import Request Output and Visualize
# #### Here, import one of the output GeoTIFFs and show some basic visualizations using the `matplotlib` package.

# %%
# Import packages
import matplotlib.pyplot as plt
import numpy as np
from osgeo import gdal
files = list(files.values())  # List files downloaded
files
# Out:
# ['HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017185_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017191_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017191_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017193_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017193_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017196_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017196_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017198_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017198_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017200_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017201_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017201_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017205_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017206_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017211_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_Fmask_doy2017211_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017185_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017191_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017191_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017193_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017193_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017196_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017196_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017198_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017198_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017200_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017201_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017201_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017205_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017206_aid0001_12N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017211_aid0001_11N.tif',
#  'HLSS30.020_2017182_to_2017212/HLSS30.020_SAA_doy2017211_aid0001_12N.tif',
#  'HLSS30-020-Fmask-lookup.csv',
#  'HLSS30-020-Fmask-Statistics-QA.csv',
#  'HLSS30-020-Statistics.csv',
#  'modis-lst-test-granule-list.txt',
#  'modis-lst-test-request.json',
#  'modis-lst-test-HLSS30-020-metadata.xml',
#  'README.md']

# %% [markdown]
# ---
# ## 6a. Import a GeoTIFF
# #### To perform the next step below, you will need to have [GDAL](http://www.gdal.org/) installed on your OS. Open the GeoTIFF file for the SRTM DEM, and read in as an array.

# %%
f = files[20].split('/')[1]
f
# Out:
# 'HLSS30.020_SAA_doy2017193_aid0001_12N.tif'

# %%
dest_file = os.path.join(destDir, f)
dest_file
# Out:
# './modis lst test/HLSS30.020_SAA_doy2017193_aid0001_12N.tif'

# %%
dem = gdal.Open(dest_file)                          # Read file in
demBand = dem.GetRasterBand(1)                      # Read the band (layer)
demData = demBand.ReadAsArray().astype('float')     # Import band as an array with type float

# %% [markdown]
# #### Next, query the metadata for the fill value, and set fill value equal to `nan`.

# %%
demFill = demBand.GetNoDataValue()            # Returns fill value
demData[demData == demFill] = np.nan          # Set fill value to nan

# %% [markdown]
# ---
# ## 6b. Plot a GeoTIFF
# #### In this section, begin by highlighting the functionality of the `matplotlib` plotting package.

# %%
# Set matplotlib plots inline
# %matplotlib inline

# %% [markdown]
# #### First, make a basic plot of the DEM data.

# %%
plt.imshow(demData);  # Visualize a basic plot of the DEM data

# %% [markdown]
# #### Next, add some additional parameters to the plot.

# %%
import warnings
warnings.filterwarnings("ignore")

fig = plt.figure(figsize = (10,7.5))  # Set the figure size (x,y)
plt.axis('off')                       # Remove the axes' values
ax = fig.add_subplot(111)

# Plot the array, using a colormap and setting a custom linear stretch based on the min/max Elevation values
plt.imshow(demData, vmin = np.nanmin(demData), vmax = np.nanmax(demData), cmap = 'terrain');

# %% [markdown]
# #### Finally, add important map items including a legend and title.

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
# <h1> Contact Information </h1>
#
# <h3> Material written by LP DAAC$^{1}$ </h3>
#
# <b>Contact:</b> LPDAAC@usgs.gov
#
# <b>Voice:</b> +1-605-594-6116
#
# <b>Organization:</b> Land Processes Distributed Active Archive Center (LP DAAC)
#
# <b>Website:</b> https://lpdaac.usgs.gov/
#
# <b>Date last modified:</b> 05-06-2022
#
# $^{1}$Innovate! Inc., contractor to the U.S. Geological Survey, Earth Resources Observation and Science (EROS) Center, Sioux Falls, South Dakota, 57198-001, USA. Work performed under USGS contract G15PD00467 for LP DAAC$^{2}$.
#
# $^{2}$LP DAAC Work performed under NASA contract NNG14HH33I.
